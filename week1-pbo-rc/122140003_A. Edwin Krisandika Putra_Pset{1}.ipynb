# %%
import random

# %%
class Robot:
    def __init__(self, name, dps, hp):
        self.name = name
        self.dps = dps
        self.hp = hp
        self.defend = False
        self.move = 0
        
    def attack(self):
        return self.dps
    
    def regen(self):
        return self.hp
    
    def __str__(self):
        return (f"{self.name}, Damage:{self.dps}, Current HP:{self.hp}")

# %%
class Game:
    def __init__(self):
        self.round = 0
        
    def beginRound(self):
        self.round += 1
        print(f"Round {self.round}")
        
    def Done(self,p1,p2):
        if p1.hp <= 0 and p2.hp > 0:
            print(f"\n{p2.name} wins!")
        elif p1.hp > 0 and p2.hp <= 0:
            print(f"\n{p1.name} wins!")
        elif p1.hp <= 0 and p2.hp <= 0:
            print(f"\nIt's a tie!")
        
        print(p1)
        print(p2)
    
    def attackAccuracy(self):
        return round(random.random(),2)
    
    def regenEffectiveness(self):
        return round(random.uniform(0,0.5),2)

# %%
play = Game()

print(f"Player 1")
name = input(f"Name : ")
dps = int(input("Damage : "))
hp = int(input("Health Point : "))
p1 = Robot(name, dps, hp)

print(f"Player 2")
name = input(f"Name : '")
dps = int(input("Damage : "))
hp = int(input("Health Point : "))
p2 = Robot(name, dps, hp)

player = [p1,p2]

gameOn = True
while(gameOn):
    print("\n_________________________________________________")
    play.beginRound()
    
    print(p1)
    print(p2)
    print("1.Attack\t2.Regen\t\t3.Defend\t4. Give up")
    for p in player:
        while p.move not in (1,2,3,4):
            p.move = int(input(f"{p.name}, Choose your move : "))
        if p.move == 3 :
            p.defend = True
            print(f"{p.name} activated their shield!")
        elif p.move == 2:
            AddHP = p.regen() * play.regenEffectiveness()
            print(f"{p.name}'s HP + {AddHP}")
            p.hp += AddHP
        elif p.move == 4:
            p.hp = 0
        print("--------------------------------------------------")
            
    if p1.move == 1:
        if p2.defend:
            print(f"{p2.name} avoided the attack! Shield broken.")
            p2.defend = False
        else:
            damage = p1.attack() * play.attackAccuracy()
            print(f"{p1.name} dealt {damage} damage!")
            p2.hp -= damage
            
    if p2.move == 1:
        if p1.defend:
            print(f"{p1.name} avoided the attack! Shield broken.")
            p1.defend = False
        else:
            damage = p2.attack() * play.attackAccuracy()
            print(f"{p2.name} dealt {damage} damage!")
            p1.hp -= damage
            
    p1.move = 0
    p2.move = 0
    
    if p1.hp <= 0 or p2.hp <= 0:
        gameOn = False
        play.Done(p1,p2)
# Out:
# Player 1
# Name : Agus
# Damage : 25
# Health Point : 100
# Player 2
# Name : 'Budi
# Damage : 30
# Health Point : 85
#
# _________________________________________________
# Round 1
# Agus, Damage:25, Current HP:100
# Budi, Damage:30, Current HP:85
# 1.Attack	2.Regen		3.Defend	4. Give up
# Agus, Choose your move : 3
# Agus activated their shield!
# --------------------------------------------------
# Budi, Choose your move : 1
# --------------------------------------------------
# Agus avoided the attack! Shield broken.
#
# _________________________________________________
# Round 2
# Agus, Damage:25, Current HP:100
# Budi, Damage:30, Current HP:85
# 1.Attack	2.Regen		3.Defend	4. Give up
# Agus, Choose your move : 1
# --------------------------------------------------
# Budi, Choose your move : 1
# --------------------------------------------------
# Agus dealt 5.0 damage!
# Budi dealt 18.0 damage!
#
# _________________________________________________
# Round 3
# Agus, Damage:25, Current HP:82.0
# Budi, Damage:30, Current HP:80.0
# 1.Attack	2.Regen		3.Defend	4. Give up
# Agus, Choose your move : 3
# Agus activated their shield!
# --------------------------------------------------
# Budi, Choose your move : 3
# Budi activated their shield!
# --------------------------------------------------
#
# _________________________________________________
# Round 4
# Agus, Damage:25, Current HP:82.0
# Budi, Damage:30, Current HP:80.0
# 1.Attack	2.Regen		3.Defend	4. Give up
# Agus, Choose your move : 1
# --------------------------------------------------
# Budi, Choose your move : 1
# --------------------------------------------------
# Budi avoided the attack! Shield broken.
# Agus avoided the attack! Shield broken.
#
# _________________________________________________
# Round 5
# Agus, Damage:25, Current HP:82.0
# Budi, Damage:30, Current HP:80.0
# 1.Attack	2.Regen		3.Defend	4. Give up
# Agus, Choose your move : 1
# --------------------------------------------------
# Budi, Choose your move : 1
# --------------------------------------------------
# Agus dealt 25.0 damage!
# Budi dealt 22.8 damage!
#
# _________________________________________________
# Round 6
# Agus, Damage:25, Current HP:59.2
# Budi, Damage:30, Current HP:55.0
# 1.Attack	2.Regen		3.Defend	4. Give up
# Agus, Choose your move : 2
# Agus's HP + 1.776
# --------------------------------------------------
# Budi, Choose your move : 2
# Budi's HP + 26.95
# --------------------------------------------------
#
# _________________________________________________
# Round 7
# Agus, Damage:25, Current HP:60.976000000000006
# Budi, Damage:30, Current HP:81.95
# 1.Attack	2.Regen		3.Defend	4. Give up
# Agus, Choose your move : 1
# --------------------------------------------------
# Budi, Choose your move : 2
# Budi's HP + 28.682499999999997
# --------------------------------------------------
# Agus dealt 1.7500000000000002 damage!
#
# _________________________________________________
# Round 8
# Agus, Damage:25, Current HP:60.976000000000006
# Budi, Damage:30, Current HP:108.8825
# 1.Attack	2.Regen		3.Defend	4. Give up
# Agus, Choose your move : 1
# --------------------------------------------------
# Budi, Choose your move : 1
# --------------------------------------------------
# Agus dealt 5.75 damage!
# Budi dealt 16.5 damage!
#
# _________________________________________________
# Round 9
# Agus, Damage:25, Current HP:44.476000000000006
# Budi, Damage:30, Current HP:103.1325
# 1.Attack	2.Regen		3.Defend	4. Give up
# Agus, Choose your move : 1
# --------------------------------------------------
# Budi, Choose your move : 1
# --------------------------------------------------
# Agus dealt 23.75 damage!
# Budi dealt 24.599999999999998 damage!
#
# _________________________________________________
# Round 10
# Agus, Damage:25, Current HP:19.87600000000001
# Budi, Damage:30, Current HP:79.3825
# 1.Attack	2.Regen		3.Defend	4. Give up
# Agus, Choose your move : 1
# --------------------------------------------------
# Budi, Choose your move : 1
# --------------------------------------------------
# Agus dealt 8.25 damage!
# Budi dealt 28.2 damage!
#
# Budi wins!
# Agus, Damage:25, Current HP:-8.323999999999991
# Budi, Damage:30, Current HP:71.1325
